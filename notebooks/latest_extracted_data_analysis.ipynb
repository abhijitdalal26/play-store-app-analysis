# %% [markdown]
# # Play Store Data Analysis
#
# Use this notebook to perform custom analysis on the exported 2026 Google Play Store dataset.
#
# ### Datasets Available:
# - `data/apps.csv`: Contains core metadata details of the scraped applications.
# - `data/app_country_stats.csv`: Contains localized download numbers, rating stats, and pricing across 10 target countries.
# - `data/discovery_signals.csv`: Contains keywords, collections, and chart rankings showing how each app was discovered.
#
# ### Loading Data with Pandas:
# ```python
# import pandas as pd
#
# apps_df = pd.read_csv('../data/apps.csv')
# stats_df = pd.read_csv('../data/app_country_stats.csv')
# signals_df = pd.read_csv('../data/discovery_signals.csv')
# ```
